# %% [markdown]
# # 🏥 MedQA-Hindi Training Notebook
#
# Run the complete training pipeline on Kaggle T4 GPU.

# %%
# Install dependencies
# !pip install -q torch transformers datasets accelerate bitsandbytes peft trl rouge-score bert-score fastapi uvicorn
# !pip install -q sentencepiece protobuf sacrebleu

# %%
# Step 1: Data Preparation
# !python data/prepare_dataset.py

# %%
# Step 2: Generate DPO pairs
# !python data/create_dpo_pairs.py

# %%
# Step 3: QLoRA Fine-tuning (~3 hours)
# !python training/qlora_finetune.py

# %%
# Step 4: DPO Alignment (~2 hours)
# !python training/dpo_align.py

# %%
# Step 5: Evaluation
# !python evaluation/evaluate.py

# %%
# Save outputs to Kaggle dataset
import shutil
shutil.make_archive('/kaggle/working/medqa-hindi-outputs', 'zip', 'outputs')
